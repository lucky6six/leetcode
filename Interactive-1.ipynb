# %% [markdown]
# 已连接到 Python 3.11.6

# %% [markdown]
# # learn to write python

# %%
'''
开头多行注释
'''
print("hello,world")
#注释
#数据类型，强制转换，无需声明
print(100,0b100,123.123,'hello',"hello")
a = True
print(type(a))
b = int(a)
print(b,type(b))

# %%
#导入库，获取输入，计算
import math

r = float(input('r'))
area = math.pi*r**2
print(area)

#同时赋值
a=1
b=2
a,b = b,a
print(a,b,123//100,123/10)
#//除以，取整，/不取整
# Out:
# 3.141592653589793
# 2 1 4 12.3

# %%
#条件语句，缩进表示层级，记得冒号.#match case 语句
height = float(input('身高(cm)：'))
weight = float(input('体重(kg)：'))
bmi = weight / (height / 100) ** 2
print(f'{bmi = :.1f}')
if bmi < 18.5:
    print('你的体重过轻！')
elif bmi < 35:
    if 18.5 <= bmi < 24:
        print('你的身材很棒！')
    else:
        print('你已肥胖！')
else:
    print('你已重度肥胖！')


status_code = int(input('响应状态码: '))
match status_code:
    case 400: description = 'Bad Request'
    case 401: description = 'Unauthorized'
    case 404: description = 'Not Found'
    case _: description = 'Unknown Status Code'
print('状态码描述:', description)
# Out:
# bmi = 27.1
# 你已肥胖！
# 状态码描述: Bad Request

# %%
#循环语句 for...in 记得冒号range常量范围
#不包括3
for i in range(3):
    print(i,end=" ")
#range() start end step_length
print("")
for i in range(2,10,3):
    print(i,end=" ")
print()
#求和0 2 4 6 8
print(sum(range(0,10,2)))

#不确定循环次数
i = 1
while i < 10:
    i+=1
print(i)
#break 跳出循环
while True:
    i-=1
    if i>5:
        #跳出迭代
        continue
    print(i,end='')
    if i<0:
        break
print()
#嵌套循环
for i in range(1, 10):
    for j in range(1, i + 1):
        #''内加{}输出变量值
        print(f'{i}×{j}={i * j}', end='\t')
    print()
# Out:
# 0 1 2
# 2 5 8
# 20
# 10
# 543210-1
# 1×1=1
# 2×1=2	2×2=4
# 3×1=3	3×2=6	3×3=9
# 4×1=4	4×2=8	4×3=12	4×4=16
# 5×1=5	5×2=10	5×3=15	5×4=20	5×5=25
# 6×1=6	6×2=12	6×3=18	6×4=24	6×5=30	6×6=36
# 7×1=7	7×2=14	7×3=21	7×4=28	7×5=35	7×6=42	7×7=49
# 8×1=8	8×2=16	8×3=24	8×4=32	8×5=40	8×6=48	8×7=56	8×8=64
# 9×1=9	9×2=18	9×3=27	9×4=36	9×5=45	9×6=54	9×7=63	9×8=72	9×9=81

# %%
#list——数组用法
it3 = [100, 12.3, 'Python', True]
#list 将序列变为列表
it5 = list('hello')
#序列拼接,乘法，访问
print(it3+it5)
print(it5*2)
print(it3[0],it3[-1])
print('C++' in it3,'Python' in it3)
#起始，终止（不包含），步长
print(it5[0:5:2])
it5[1:3] = [0,0]
print(it5) 
#元素遍历,数值索引，元素索引
languages = ['Python', 'Java', 'C++']
for index in range(len(languages)):
    print(languages[index],end='')
for language in languages:
    print(language,end='')
print()
#嵌套数组
it=[it3,it5]
print(it)
# Out:
# [100, 12.3, 'Python', True, 'h', 'e', 'l', 'l', 'o']
# ['h', 'e', 'l', 'l', 'o', 'h', 'e', 'l', 'l', 'o']
# 100 True
# False True
# ['h', 'l', 'o']
# ['h', 0, 0, 'l', 'o']
# PythonJavaC++PythonJavaC++
# [[100, 12.3, 'Python', True], ['h', 0, 0, 'l', 'o']]

# %%
#list——迭代器
languages = ['Python', 'Java', 'C++']
languages.append('JavaScript')
print(languages) 
languages.insert(1, 'SQL')
if 'Java' in languages:
    languages.remove('Java')
print(languages)  
languages.pop()
temp = languages.pop(1)
print(temp)       # SQL
for _ in range(3):
    languages.append('c++')
print(languages.index('c++'))
print(languages.count('c++'))
languages.remove('c++')#只remove第一个
print(languages)
languages.sort()
print(languages)
languages.reverse()
print(languages)
languages.clear()
# Out:
# ['Python', 'Java', 'C++', 'JavaScript']
# ['Python', 'SQL', 'C++', 'JavaScript']
# SQL
# 2
# 3
# ['Python', 'C++', 'c++', 'c++']

# %%
a=(1,2,3)
q,w,e = a
b = list(a)
print(a,b,q,w,e)
#tuple不可变列表（元组），会快一点，也可以和list相互转换
s1 = 'hello, world'
s2 = 'goodbye, world'
print('wo' in s1)      # True
print('wo' not in s2)  # False
print(s2 in s1)        # False
# 字符串首字母大写
print(s1.capitalize())  # Hello, world!
# 字符串每个单词首字母大写
print(s1.title())       # Hello, World!
# 字符串变大写
print(s1.upper())       # HELLO, WORLD!
s2 = 'GOODBYE'
# 字符串变小写
print(s2.lower())       # goodbye
# 检查s1和s2的值
print(s1)               # hello, world
print(s2)               # GOODBYE
#字符串也类似
s = 'hello, world!'
print(s.find('or'))      # 8
print(s.find('or', 9))   # -1
print(s.find('of'))      # -1
# print(s.index('or', 9))  # ValueError: substring not found
#说明：find方法找不到指定的字符串会返回-1，index方法找不到指定的字符串会引发ValueError错误。
#字符串切分与合并
s = 'I love you'
words = s.split()
a='~'.join(words)
print(words)            # ['I', 'love', 'you']
print(a)  # I~love~you
s = 'I#love#you#so#much'
words = s.split('#')
print(words)  # ['I', 'love', 'you', 'so', 'much']
# Out:
# (1, 2, 3) [1, 2, 3] 1 2 3
# True
# False
# False
# Hello, world
# Hello, World
# HELLO, WORLD
# goodbye
# hello, world
# GOODBYE
# 8
# -1
# -1
# 8
# ['I', 'love', 'you']
# I~love~you
# ['I', 'love', 'you', 'so', 'much']

# %%
set1 = {'Python', 'C++', 'Java', 'Kotlin', 'Swift'}
for elem in set1:
    print(elem)

set1 = {1, 2, 3, 4, 5, 6, 7}
set2 = {2, 4, 6, 8, 10}
# 交集
print(set1 & set2)                      # {2, 4, 6}
print(set1.intersection(set2))          # {2, 4, 6}
# 并集
print(set1 | set2)                      # {1, 2, 3, 4, 5, 6, 7, 8, 10}
print(set1.union(set2))                 # {1, 2, 3, 4, 5, 6, 7, 8, 10}
# 差集
print(set1 - set2)                      # {1, 3, 5, 7}
print(set1.difference(set2))            # {1, 3, 5, 7}
# 比较，区分子集与真子集
set1 = {1, 3, 5}
set2 = {1, 2, 3, 4, 5}
set3 = {5, 4, 3, 2, 1}
print(set1 < set2)   # True
print(set1 <= set2)  # True
print(set2 < set3)   # False
print(set2 <= set3)  # True
print(set2 > set1)   # True
print(set2 == set3)  # True
#删除集合元素的remove方法在元素不存在时会引发KeyError错误，所以上面的代码中我们先通过成员运算判断元素是否在集合中。
#集合类型还有一个pop方法可以从集合中随机删除一个元素，该方法在删除元素的同时会获得被删除的元素，
# 而remove和discard方法仅仅是删除元素，不会获得被删除的元素。
# Out:
# Kotlin
# C++
# Python
# Swift
# Java

# %%
#字典dict——类似map
# dict函数(构造器)中的每一组参数就是字典中的一组键值对
person = dict(name='王大锤', age=55, height=168, weight=60, addr='成都市武侯区科华北路62号1栋101')
print(person)  # {'name': '王大锤', 'age': 55, 'height': 168, 'weight': 60, 'addr': '成都市武侯区科华北路62号1栋101'}
items2 = dict(zip('ABCDE', range(1, 10)))
print(items2)  # {'A': 1, 'B': 2, 'C': 3, 'D': 4, 'E': 5}
print(len(person))  # 5
for key in person:
    print(key)
    print(f'{key}:\t{person[key]}')
print(person['addr'])
person['age'] = 25
print(person.keys())    # dict_keys(['name', 'age', 'height'])
print(person.values())  # dict_values(['王大锤', 25, 178])
print(person.items())   # dict_items([('name', '王大锤'), ('age', 25), ('height', 178)])
print(person.pop('age'))  # 25
del person['addr']
print(person)  # {'name': '王大锤', 'height': 178}

# %%
#函数
# 函数的自变量n表示色子的个数，默认值为2
# 函数的返回值表示摇n颗色子得到的点数
def roll_dice(n=2):
    total = 0
    for _ in range(n):
        total += randrange(1, 7)
    return total
# 用星号表达式来表示args可以接收0个或任意多个参数
# 调用函数时传入的n个参数会组装成一个n元组赋给args
# 如果一个参数都没有传入，那么args会是一个空元组
def add(*args):
    total = 0
    # 对保存可变参数的元组进行循环遍历
    for val in args:
        # 对参数进行了类型检查（数值型的才能求和）
        if type(val) in (int, float):
            total += val
    return total
# 参数列表中的**kwargs可以接收0个或任意多个关键字参数
# 调用函数时传入的关键字参数会组装成一个字典（参数名是字典中的键，参数值是字典中的值）
# 如果一个关键字参数都没有传入，那么kwargs会是一个空字典
def foo(*args, **kwargs):
    print(args)
    print(kwargs)

print(add(1, 2, 'hello', 3.45, 6))  # 12.45
foo(3, 2.1, True, name='骆昊', age=43, gpa=4.95)

#import 手动引入模块，防止重名函数冲突
